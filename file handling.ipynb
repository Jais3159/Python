# %%
import os

folder_path = r"C:\Users\Jashan\OneDrive\Desktop\Engagement_soft[1].docx"

try:
    # os.startfile opens the path with the default application (File Explorer for a folder)
    os.startfile(folder_path)
    print(f"Successfully launched File Explorer for: {folder_path}")
except FileNotFoundError:
    print(f"Error: The directory was not found at the path: {folder_path}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The directory was not found at the path: C:\Users\Jashan\OneDrive\Desktop\Engagement_soft[1].docx

# %%
import os
if os.path.exists('file1.txt'):
    print('File exists')
else:
    print('file does not exists')
# Out:
# file does not exists

# %%
import os
if os.path.isfile('file1.txt'):
    print('It is a file')
else:
    print('It is not a file')
# Out:
# It is not a file

# %%
import os
os.remove('file2.txt')
print('File deleted')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 import os
# ----> 2 os.remove('file2.txt')
#       3 print('File deleted')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'file2.txt'

# %%
import osfile_path
