# %%
# Exception handling
# try         
# except      
# else        
# raise       
# finally     
# maths ke jitne bhi error hote hai voh saare value type error hote hai.

# %%
try:
    print(x)
except:
    print('An exception has occured')
# Out:
# An exception has occured

# %%
try:        # use tab krte hai jab execute krne ka try kre
    number = int(input('Enter a number: '))
    result = 10 / number
    print(result)
except ZeroDivisionError:
    print('You cannot divide by zero!')
except ValueError:
    print("That's not a valid number!")
# Out:
# 1.0

# %%
try:
    even_numbers = [2,4,6,8]
    print(even_numbers[5])
except ZeroDivisionError:
    print('Denominator cannot be 0')
except IndexError:
    print('Index out of bound')
# Out:
# Index out of bound

# %%
try:
    number = int(input('Enter the number: '))
    result = 10 / number
    print(result)
except(ZeroDivisionError, ValueError) as e:
    print(f'An error occured: {e}')
# Out:
# 2.0

# %%
try:
    print('Hello!!')
except:
    print('Something went wrong')
else:
    print('Nothing went wrong')
# Out:
# Hello!!
# Nothing went wrong

# %%
try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
except:
    print('Error: Denominator cannot be 0')
finally:
    print('This is finally block')
# Out:
# Error: Denominator cannot be 0
# This is finally block

# %%
value  = int(input('Enter any value: '))
if value > 1000:
    raise ValueError('Please add a value lower than 1000')
else:
    print('Congratulations! You are the winner!')
# Out:
# Congratulations! You are the winner!

# %%
number = int(input('Enter the number: '))
try:
    print(number ** 2)
except ValueError:
    print('Error: Not an integer')
else:
    print('No error')
# Out:
# 25
# No error

# %%
age = int(input('Enter the age: '))
try: 
    if age < 0:
        print('Age cannot be negative')
except ValueError as e:
    print('error', e)
finally:
    print('No error')
# Out:
# No error

# %%
list1 = ["hello","how","are","you"]
list2 = ["rama",1,2,3,4,5]
list3 = list1 + list2
print(list3[6])
try:
    print(list3[12])
except IndexError:
    print(list4[1])
# Out:
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 6
#       5 try:
# ----> 6     print(list3[12])
#       7 except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 8
#       6     print(list3[12])
#       7 except IndexError:
# ----> 8     print(list4[1])
#
# NameError: name 'list4' is not defined
